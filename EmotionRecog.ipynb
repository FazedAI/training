# %% [markdown]
# <a href="https://colab.research.google.com/github/FazedAI/training/blob/master/EmotionRecog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/priya-dwivedi/face_and_emotion_detection.git
# Out:
# Cloning into 'face_and_emotion_detection'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 48 (delta 19), reused 48 (delta 19), pack-reused 0
# Unpacking objects: 100% (48/48), done.

# %%
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np
import face_recognition
import keras
from keras.models import load_model
import cv2

# %%
image1 = Image.open("leo.jpg")
image_array = np.array(image1)
plt.imshow(image_array)

# %%
image = face_recognition.load_image_file("leo.jpg")
face_locations = face_recognition.face_locations(image)

# %%
face_locations
# Out:
# [(46, 116, 136, 26)]

# %%
top, right, bottom, left = face_locations[0]
face_image2 = image[top:bottom, left:right]
plt.imshow(face_image2)
image_save = Image.fromarray(face_image2)
image_save.save("image_2.jpg")

# %%
emotion_dict = {'Angry': 0, 'Sad': 5, 'Neutral': 4, 'Disgust': 1, 'Surprise': 6, 'Fear': 2, 'Happy': 3}

# %%
face_image = cv2.imread('/content/IMFDB_final/MadhuriDixit/HumApkeHaiKoun/images/MadhuriDixit_111.jpg')
plt.imshow(face_image)

# %%
print(face_image.shape)
# Out:
# (88, 71, 3)

# %%
face_image = cv2.resize(face_image, (48,48))
face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY)
face_image = np.reshape(face_image, [1, face_image.shape[0], face_image.shape[1], 1])

# %%
model = load_model("face_and_emotion_detection/emotion_detector_models/model_v6_23.hdf5")

# %%
predicted_class = np.argmax(model.predict(face_image))

# %%
label_map = dict((v, k) for k, v in emotion_dict.items())
predicted_label = label_map[predicted_class]

# %%
print(predicted_label)
# Out:
# Happy
